# %% [markdown]
# # 1. Frame the problem
# Given a sample of several hundred emails labelled as either spam or not spam (aka ham), predict whether an inputted email is spam or not based on differences that can be found between spam emails and normal emails. Ex. words such as "free, email, send" are commonly used in spam emails to attempt to attract a victim. Emails with a high density of these words are likely spam emails.

# %% [markdown]
# # 2. Get the Data
# - The data was provided in a folder called "mail" as 872 text files labelled as either spam emails or non spam (ham) emails.
# - To initially load the data, I loop through every single text file and add its contents to a pandas dataframe.
# - I also have a boolean column for each email that states whether it is spam or not.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

columnaxis = []

for filename in os.listdir("mail"): #loop through a list of every email filename in the mail folder
    if not os.path.isdir(filename):
        with open("mail/" + filename, 'r') as file: #open each file
            spambool = "spm" in filename #create boolean based on whether the email is spam or not
            content = file.read() #get text contents of file, aka the actual email
            row = [spambool, content] #create row array
            columnaxis.append(row) #add to list that will become a dataframe
dataframe = pd.DataFrame(columnaxis, columns=['Spam', 'Content'])

# columns: Spam, Content

# all modifications to dataset go under here
print(str(len(dataframe)) + " rows in dataframe")
# Out:
# 872 rows in dataframe

# %% [markdown]
# - Before doing anything else, create a test train split (see step 4 as to why)

# %%
from sklearn.model_selection import train_test_split

# creating feature variables
dataframe_X = dataframe.drop(columns=['Spam']) #get all columns but the spam column
dataframe_Y = dataframe['Spam'] #get only the spam column

X_train, X_test, Y_train, Y_test = train_test_split(dataframe_X, dataframe_Y, test_size=0.3, random_state=42)

dataframe_train = pd.DataFrame() #creates new dataframe thatis just all the training data
dataframe_train["Content"] = X_train.Content
dataframe_train["Spam"] = Y_train.to_frame().Spam

# %% [markdown]
# # 3. Explore the Data
# - Below is a data explorer that just allows you to look thru the dataset in pages for easy searching (for this email spam project in particular it isn't that useful)

# %%
#copied from project 1, used to explore the data in pages
from IPython.display import clear_output #so that output is cleared after every page to prevent clutter and huge outputs

pd.set_option('display.max_columns', None) #unrestrict amount of columns printable
pd.set_option('display.max_rows', None)  #unrestrict amount of rows printable
pd.set_option('display.max_colwidth', None)  #unrestrict printable width of columns

#a little page search thing to view the data
x = 1
resultsperpage = 10
while x >= 1:
    print("Page " + str(x) + ":")
    clear_output()
    print(dataframe_train[resultsperpage * (x - 1):resultsperpage * (x)])
    x = int(input("Input a page number: "))

# %% [markdown]
# - Before vizualizing the data, I need to clean the data (see step 4 for details)

# %%
import string #for getting all forms of punctuation to remove
import nltk
nltk.download('punkt') #nltk doesnt work if i dont do this stuff for some reason
nltk.download('wordnet') #nltk doesnt work if i dont do this stuff for some reason
from nltk.stem import PorterStemmer, WordNetLemmatizer#stemming is like getting rid of tenses and stuff to make as many words in common as possible. found out lemmatizing is useless after some tests, for some reason it just removes "s" at the end if it exists
from nltk.tokenize import word_tokenize #split emails into words (better than .split cuz it handles multiple spaces well)

ps = PorterStemmer() #create stemming obj
wnl = WordNetLemmatizer()
print("THIS CODE TAKES A COUPLE SECONDS TO RUN DUE TO ALL THE STEMMING...")

def clean(content): #this function will be applied to the contents of each email
    ret = ""
    content = content.translate(str.maketrans('', '', string.punctuation)) #removes punctuation
    for word in word_tokenize(content):
        word == ps.stem(word) #stem word first
        ret += wnl.lemmatize(word) + " " #then lemmatize and add it to a string
        # if word != ps.stem(word): #debug code that would show all the changes made by stemming. HUGE OUTPUT DO NOT UNCOMMENT UNLESS YOU WANT TO DIE
        # if word != wnl.lemmatize(word): #debug code that would show all the changes made by stemming. HUGE OUTPUT DO NOT UNCOMMENT UNLESS YOU WANT TO DIE
            # print(word + " >> " + ps.stem(word))
            # print(word + " >> " + wnl.lemmatize(word))
    return ret
dataframe_train['ContentCleaned'] = dataframe_train.Content.apply(clean) #apply above function to every email in df
print("done")
print(dataframe_train.Content[0])
print(dataframe_train.ContentCleaned[0])
# Out:
# [nltk_data] Downloading package punkt to /home/jupyter-
# [nltk_data]     victorj/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/jupyter-
# [nltk_data]     victorj/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# THIS CODE TAKES A COUPLE SECONDS TO RUN DUE TO ALL THE STEMMING...
# less >> le
# ems >> em
# ems >> em
# ems >> em
# ems >> em
# ems >> em
# ems >> em
# ems >> em
# ems >> em
# ems >> em
# ems >> em
# ems >> em
# us >> u
# millions >> million
# roms >> rom
# supplies >> supply
# us >> u
# drives >> drive
# deals >> deal
# less >> le
# less >> le
# us >> u
# drives >> drive
# cashiers >> cashier
# us >> u
# funds >> fund
# deals >> deal
# means >> mean
# drives >> drive
# cashiers >> cashier
# us >> u
# funds >> fund
# deals >> deal
# engines >> engine
# sites >> site
# links >> link
# classifieds >> classified
# ads >> ad
# links >> link
# adams >> adam
# links >> link
# ads >> ad
# classifieds >> classified
# links >> link
# ams >> am
# ams >> am
# links >> link
# links >> link
# links >> link
# classifieds >> classified
# links >> link
# links >> link
# links >> link
# links >> link
# seeks >> seek
# links >> link
# links >> link
# sites >> site
# cs >> c
# links >> link
# links >> link
# des >> de
# links >> link
# links >> link
# links >> link
# links >> link
# links >> link
# eccs >> ecc
# links >> link
# links >> link
# exes >> ex
# links >> link
# links >> link
# classifieds >> classified
# links >> link
# links >> link
# links >> link
# gcs >> gc
# gs >> g
# hits >> hit
# links >> link
# links >> link
# links >> link
# links >> link
# links >> link
# links >> link
# links >> link
# services >> service
# links >> link
# links >> link
# links >> link
# links >> link
# links >> link
# links >> link
# links >> link
# links >> link
# links >> link
# links >> link
# links >> link
# links >> link
# links >> link
# links >> link
# links >> link
# links >> link
# links >> link
# ads >> ad
# links >> link
# ads >> ad
# pages >> page
# links >> link
# links >> link
# links >> link
# links >> link
# classifieds >> classified
# sos >> so
# links >> link
# classifieds >> classified
# links >> link
# tbs >> tb
# links >> link
# links >> link
# links >> link
# links >> link
# links >> link
# links >> link
# links >> link
# links >> link
# links >> link
# links >> link
# links >> link
# links >> link
# links >> link
# systems >> system
# links >> link
# links >> link
# links >> link
# creations >> creation
# links >> link
# makers >> maker
# tools >> tool
# links >> link
# links >> link
# links >> link
# links >> link
# classifieds >> classified
# ads >> ad
# links >> link
# links >> link
# pays >> pay
# urls >> url
# cashiers >> cashier
# us >> u
# funds >> fund
# deals >> deal
# releases >> release
# us >> u
# releases >> release
# adults >> adult
# children >> child
# adults >> adult
# pass >> pas
# hundreds >> hundred
# dollars >> dollar
# discounts >> discount
# tickets >> ticket
# days >> day
# nights >> night
# days >> day
# nights >> night
# incidentals >> incidental
# means >> mean
# times >> time
# us >> u
# times >> time
# means >> mean
# dollars >> dollar
# profits >> profit
# us >> u
# millionaires >> millionaire
# us >> u
# us >> u
# us >> u
# us >> u
# us >> u
# exceptions >> exception
# papers >> paper
# us >> u
# us >> u
# continua >> continuum
# less >> le
# addresses >> address
# less >> le
# profits >> profit
# less >> le
# addresses >> address
# specials >> special
# us >> u
# hours >> hour
# discuss >> discus
# discuss >> discus
# discuss >> discus
# papers >> paper
# discuss >> discus
# papers >> paper
# discuss >> discus
# papers >> paper
# discuss >> discus
# hindus >> hindu
# us >> u
# italics >> italic
# discuss >> discus
# regards >> regard
# hindus >> hindu
# papers >> paper
# papers >> paper
# discuss >> discus
# papers >> paper
# grounds >> ground
# us >> u
# dos >> do
# dos >> do
# works >> work
# thousands >> thousand
# millions >> million
# orders >> order
# millions >> million
# hundreds >> hundred
# dollars >> dollar
# hours >> hour
# hits >> hit
# less >> le
# hours >> hour
# millions >> million
# hits >> hit
# hits >> hit
# millions >> million
# millions >> million
# minutes >> minute
# addresses >> address
# sites >> site
# readers >> reader
# millions >> million
# millions >> million
# millions >> million
# millions >> million
# orders >> order
# orders >> order
# millions >> million
# millions >> million
# millions >> million
# sites >> site
# instructions >> instruction
# hundreds >> hundred
# rights >> right
# reports >> report
# rights >> right
# days >> day
# days >> day
# us >> u
# questions >> question
# billions >> billion
# cis >> ci
# instructions >> instruction
# us >> u
# us >> u
# us >> u
# us >> u
# us >> u
# markers >> marker
# contents >> content
# prospects >> prospect
# us >> u
# us >> u
# discuss >> discus
# discuss >> discus
# us >> u
# us >> u
# us >> u
# us >> u
# us >> u
# us >> u
# contents >> content
# less >> le
# papers >> paper
# pass >> pas
# instructions >> instruction
# benefits >> benefit
# instructions >> instruction
# hundreds >> hundred
# orders >> order
# reports >> report
# sales >> sale
# corporations >> corporation
# sales >> sale
# sources >> source
# lists >> list
# sales >> sale
# plans >> plan
# totals >> total
# tips >> tip
# orders >> order
# ms >> m
# pass >> pas
# reports >> report
# papers >> paper
# papers >> paper
# references >> reference
# us >> u
# discuss >> discus
# returns >> return
# less >> le
# makes >> make
# associates >> associate
# lists >> list
# names >> name
# us >> u
# names >> name
# rights >> right
# fundings >> funding
# us >> u
# us >> u
# us >> u
# rights >> right
# types >> type
# hours >> hour
# us >> u
# hours >> hour
# hours >> hour
# us >> u
# us >> u
# dealers >> dealer
# copies >> copy
# programs >> program
# less >> le
# prices >> price
# supplies >> supply
# us >> u
# instructions >> instruction
# us >> u
# us >> u
# us >> u
# us >> u
# stocks >> stock
# squires >> squire
# methods >> method
# humanities >> humanity
# methods >> method
# statistics >> statistic
# papers >> paper
# statistics >> statistic
# us >> u
# us >> u
# papers >> paper
# papers >> paper
# papers >> paper
# papers >> paper
# papers >> paper
# instructions >> instruction
# contributors >> contributor
# proceedings >> proceeding
# papers >> paper
# payments >> payment
# methods >> method
# languages >> language
# speakers >> speaker
# abstracts >> abstract
# papers >> paper
# less >> le
# ideas >> idea
# applicants >> applicant
# possess >> posse
# less >> le
# us >> u
# us >> u
# taus >> tau
# us >> u
# us >> u
# us >> u
# us >> u
# speakers >> speaker
# us >> u
# us >> u
# discuss >> discus
# papers >> paper
# updates >> update
# features >> feature
# updates >> update
# updates >> update
# us >> u
# less >> le
# discuss >> discus
# papers >> paper
# contents >> content
# papers >> paper
# less >> le
# papers >> paper
# less >> le
# us >> u
# us >> u
# papers >> paper
# papers >> paper
# papers >> paper
# goods >> good
# papers >> paper
# discuss >> discus
# discuss >> discus
# discuss >> discus
# guidelines >> guideline
# copies >> copy
# pages >> page
# files >> file
# keys >> key
# dates >> date
# regards >> regard
# us >> u
# us >> u
# aus >> au
# papers >> paper
# us >> u
# taxes >> tax
# laws >> law
# bandits >> bandit
# has >> ha
# paychecks >> paycheck
# rights >> right
# papers >> paper
# papers >> paper
# papers >> paper
# papers >> paper
# papers >> paper
# papers >> paper
# savings >> saving
# us >> u
# checks >> check
# us >> u
# os >> o
# dos >> do
# us >> u
# children >> child
# dps >> dp
# massachusetss >> massachuset
# children >> child
# children >> child
# children >> child
# children >> child
# umass >> uma
# umass >> uma
# us >> u
# rus >> ru
# us >> u
# physics >> physic
# us >> u
# hours >> hour
# resources >> resource
# resources >> resource
# adds >> add
# projects >> project
# shares >> share
# damages >> damage
# us >> u
# less >> le
# revenues >> revenue
# hours >> hour
# us >> u
# hours >> hour
# us >> u
# discuss >> discus
# boss >> bos
# prospects >> prospect
# makes >> make
# us >> u
# submissions >> submission
# papers >> paper
# papers >> paper
# organisers >> organiser
# addresses >> address
# specifications >> specification
# papers >> paper
# has >> ha
# pass >> pas
# vs >> v
# vs >> v
# shares >> share
# cs >> c
# vs >> v
# responses >> response
# vs >> v
# regards >> regard
# improvements >> improvement
# papers >> paper
# bas >> ba
# bas >> ba
# structures >> structure
# less >> le
# papers >> paper
# nps >> np
# nps >> np
# girls >> girl
# girls >> girl
# girls >> girl
# less >> le
# papers >> paper
# folks >> folk
# means >> mean
# us >> u
# less >> le
# means >> mean
# sycophants >> sycophant
# less >> le
# means >> mean
# means >> mean
# aus >> au
# aus >> au
# ancients >> ancient
# qs >> q
# dos >> do
# us >> u
# us >> u
# us >> u
# us >> u
# us >> u
# discuss >> discus
# us >> u
# discuss >> discus
# us >> u
# us >> u
# us >> u
# entrepreneurs >> entrepreneur
# casinos >> casino
# las >> la
# las >> la
# instructions >> instruction
# less >> le
# places >> place
# pass >> pas
# instructions >> instruction
# benefits >> benefit
# hundreds >> hundred
# orders >> order
# reports >> report
# corporations >> corporation
# sources >> source
# lists >> list
# us >> u
# sales >> sale
# plans >> plan
# totals >> total
# tips >> tip
# orders >> order
# ms >> m
# pass >> pas
# pass >> pas
# reports >> report
# means >> mean
# savings >> saving
# cents >> cent
# us >> u
# images >> image
# experts >> expert
# stars >> star
# savings >> saving
# less >> le
# less >> le
# us >> u
# us >> u
# instructions >> instruction
# benefits >> benefit
# problems >> problem
# hundreds >> hundred
# orders >> order
# reports >> report
# checks >> check
# reports >> report
# sales >> sale
# corporations >> corporation
# sales >> sale
# sources >> source
# lists >> list
# sales >> sale
# plans >> plan
# totals >> total
# tips >> tip
# orders >> order
# guidelines >> guideline
# ms >> m
# pass >> pas
# works >> work
# pass >> pas
# pass >> pas
# reports >> report
# yields >> yield
# results >> result
# papers >> paper
# papers >> paper
# papers >> paper
# contents >> content
# es >> e
# programs >> program
# programs >> program
# us >> u
# us >> u
# us >> u
# channels >> channel
# events >> event
# less >> le
# photos >> photo
# plans >> plan
# does >> doe
# families >> family
# bills >> bill
# orders >> order
# fees >> fee
# hrs >> hr
# media >> medium
# aus >> au
# os >> o
# os >> o
# dos >> do
# os >> o
# papers >> paper
# dentures >> denture
# hundreds >> hundred
# cars >> car
# suvs >> suv
# minivans >> minivan
# trucks >> truck
# rvs >> rv
# us >> u
# us >> u
# less >> le
# less >> le
# bargains >> bargain
# cds >> cd
# djs >> dj
# bargains >> bargain
# cds >> cd
# likes >> like
# djs >> dj
# shares >> share
# cars >> car
# less >> le
# requirements >> requirement
# means >> mean
# savings >> saving
# questions >> question
# us >> u
# testimonials >> testimonial
# questions >> question
# pass >> pas
# seconds >> second
# us >> u
# discuss >> discus
# papers >> paper
# papers >> paper
# css >> cs
# papers >> paper
# papers >> paper
# us >> u
# cosigners >> cosigner
# us >> u
# us >> u
# rights >> right
# companies >> company
# addresses >> address
# rights >> right
# us >> u
# us >> u
# us >> u
# us >> u
# us >> u
# us >> u
# us >> u
# us >> u
# us >> u
# us >> u
# us >> u
# has >> ha
# us >> u
# less >> le
# us >> u
# dats >> dat
# dats >> dat
# dats >> dat
# dats >> dat
# dats >> dat
# dats >> dat
# dats >> dat
# dats >> dat
# dats >> dat
# means >> mean
# dats >> dat
# dats >> dat
# dats >> dat
# dats >> dat
# dats >> dat
# dats >> dat
# dats >> dat
# dats >> dat
# dats >> dat
# dats >> dat
# dats >> dat
# dats >> dat
# means >> mean
# dats >> dat
# dats >> dat
# nps >> np
# dats >> dat
# papers >> paper
# us >> u
# casinos >> casino
# las >> la
# las >> la
# us >> u
# workings >> working
# developments >> development
# hindus >> hindu
# ems >> em
# less >> le
# ems >> em
# ems >> em
# ems >> em
# ems >> em
# ems >> em
# ems >> em
# ems >> em
# ems >> em
# ems >> em
# ems >> em
# ems >> em
# us >> u
# millions >> million
# roms >> rom
# supplies >> supply
# us >> u
# discuss >> discus
# us >> u
# discuss >> discus
# papers >> paper
# gis >> gi
# papers >> paper
# sales >> sale
# cards >> card
# fees >> fee
# transactions >> transaction
# seconds >> second
# assets >> asset
# makes >> make
# us >> u
# rights >> right
# topics >> topic
# theories >> theory
# papers >> paper
# organizers >> organizer
# discuss >> discus
# papers >> paper
# papers >> paper
# dates >> date
# zus >> zu
# us >> u
# humanities >> humanity
# humanities >> humanity
# humanities >> humanity
# humanities >> humanity
# humanities >> humanity
# humanities >> humanity
# papers >> paper
# us >> u
# papers >> paper
# papers >> paper
# dynamics >> dynamic
# papers >> paper
# papers >> paper
# structures >> structure
# us >> u
# us >> u
# papers >> paper
# papers >> paper
# dynamics >> dynamic
# papers >> paper
# papers >> paper
# offers >> offer
# limitations >> limitation
# hours >> hour
# us >> u
# supplies >> supply
# supplies >> supply
# us >> u
# us >> u
# specifics >> specific
# languages >> language
# discuss >> discus
# computers >> computer
# materials >> material
# us >> u
# taxes >> tax
# months >> month
# politicians >> politician
# trusts >> trust
# reprints >> reprint
# rights >> right
# digits >> digit
# does >> doe
# trusts >> trust
# efforts >> effort
# sales >> sale
# sales >> sale
# statistics >> statistic
# sales >> sale
# us >> u
# us >> u
# less >> le
# returns >> return
# presses >> press
# us >> u
# us >> u
# us >> u
# us >> u
# us >> u
# programs >> program
# means >> mean
# hours >> hour
# boss >> bos
# rights >> right
# less >> le
# goods >> good
# statistics >> statistic
# less >> le
# orders >> order
# weeks >> week
# programs >> program
# orders >> order
# weeks >> week
# programs >> program
# orders >> order
# works >> work
# us >> u
# dollars >> dollar
# works >> work
# programs >> program
# instructions >> instruction
# works >> work
# orders >> order
# reports >> report
# reports >> report
# positions >> position
# reports >> report
# orders >> order
# reports >> report
# sales >> sale
# corporations >> corporation
# sales >> sale
# sources >> source
# lists >> list
# sales >> sale
# plans >> plan
# steps >> step
# reports >> report
# reports >> report
# rights >> right
# reports >> report
# reports >> report
# pass >> pas
# discuss >> discus
# discuss >> discus
# regards >> regard
# us >> u
# less >> le
# us >> u
# means >> mean
# refreshments >> refreshment
# picks >> pick
# handicappers >> handicapper
# us >> u
# us >> u
# picks >> pick
# picks >> pick
# us >> u
# us >> u
# us >> u
# papers >> paper
# developments >> development
# speakers >> speaker
# developments >> development
# papers >> paper
# accommodations >> accommodation
# conferences >> conference
# prospects >> prospect
# prospects >> prospect
# prospects >> prospect
# prospects >> prospect
# us >> u
# hours >> hour
# us >> u
# us >> u
# dollars >> dollar
# us >> u
# hours >> hour
# us >> u
# us >> u
# us >> u
# us >> u
# us >> u
# dollars >> dollar
# us >> u
# dollars >> dollar
# us >> u
# us >> u
# dollars >> dollar
# correspondences >> correspondence
# needless >> needle
# phds >> phd
# phds >> phd
# words >> word
# papers >> paper
# papers >> paper
# us >> u
# communications >> communication
# des >> de
# les >> le
# resumes >> resume
# us >> u
# regards >> regard
# tetris >> tetri
# politicians >> politician
# needs >> need
# suits >> suit
# us >> u
# rights >> right
# us >> u
# means >> mean
# bonuses >> bonus
# rights >> right
# us >> u
# us >> u
# studies >> study
# languages >> language
# studies >> study
# umass >> uma
# papers >> paper
# exhibits >> exhibit
# applications >> application
# topics >> topic
# papers >> paper
# papers >> paper
# authors >> author
# copies >> copy
# clips >> clip
# roma >> rom
# papers >> paper
# exhibits >> exhibit
# activities >> activity
# papers >> paper
# less >> le
# less >> le
# women >> woman
# kits >> kit
# proceedings >> proceeding
# papers >> paper
# papers >> paper
# proceedings >> proceeding
# papers >> paper
# papers >> paper
# discuss >> discus
# papers >> paper
# hindus >> hindu
# hindus >> hindu
# papers >> paper
# discuss >> discus
# discuss >> discus
# means >> mean
# ds >> d
# ds >> d
# discuss >> discus
# papers >> paper
# papers >> paper
# pass >> pas
# less >> le
# papers >> paper
# ss >> s
# ds >> d
# ss >> s
# databases >> database
# blinders >> blinder
# discuss >> discus
# papers >> paper
# papers >> paper
# physics >> physic
# papers >> paper
# papers >> paper
# papers >> paper
# pass >> pas
# less >> le
# pass >> pas
# less >> le
# orders >> order
# weeks >> week
# programs >> program
# orders >> order
# weeks >> week
# programs >> program
# orders >> order
# works >> work
# ps >> p
# us >> u
# dollars >> dollar
# us >> u
# works >> work
# programs >> program
# goods >> good
# us >> u
# statistics >> statistic
# instructions >> instruction
# works >> work
# orders >> order
# reports >> report
# reports >> report
# positions >> position
# reports >> report
# orders >> order
# reports >> report
# sales >> sale
# corporations >> corporation
# sales >> sale
# sources >> source
# lists >> list
# sales >> sale
# plans >> plan
# steps >> step
# reports >> report
# reports >> report
# rights >> right
# reports >> report
# reports >> report
# was >> wa
# tips >> tip
# reports >> report
# us >> u
# reports >> report
# orders >> order
# guarantees >> guarantee
# dares >> dare
# ps >> p
# colors >> color
# colors >> color
# us >> u
# us >> u
# discuss >> discus
# folks >> folk
# grounds >> ground
# dentures >> denture
# physics >> physic
# means >> mean
# physics >> physic
# gestalten >> gestalt
# less >> le
# updates >> update
# fees >> fee
# methods >> method
# contents >> content
# contents >> content
# discuss >> discus
# pass >> pas
# pass >> pas
# pass >> pas
# pass >> pas
# less >> le
# speakers >> speaker
# less >> le
# weeks >> week
# seconds >> second
# days >> day
# laws >> law
# sections >> section
# states >> state
# products >> product
# services >> service
# comes >> come
# sites >> site
# advertisers >> advertiser
# services >> service
# spots >> spot
# programs >> program
# us >> u
# products >> product
# services >> service
# us >> u
# rates >> rate
# rates >> rate
# discuss >> discus
# means >> mean
# us >> u
# savings >> saving
# us >> u
# groceries >> grocery
# books >> book
# papers >> paper
# topics >> topic
# submissions >> submission
# papers >> paper
# papers >> paper
# deadlines >> deadline
# ens >> en
# organizers >> organizer
# us >> u
# means >> mean
# dollars >> dollar
# us >> u
# us >> u
# us >> u
# us >> u
# us >> u
# us >> u
# exceptions >> exception
# us >> u
# hills >> hill
# us >> u
# papers >> paper
# papers >> paper
# dues >> due
# pages >> page
# pages >> page
# gis >> gi
# lis >> li
# pages >> page
# sites >> site
# engines >> engine
# sports >> sport
# sites >> site
# sites >> site
# papers >> paper
# papers >> paper
# means >> mean
# papers >> paper
# rights >> right
# boss >> bos
# rights >> right
# rights >> right
# dealings >> dealing
# rights >> right
# rights >> right
# bas >> ba
# bas >> ba
# bas >> ba
# ms >> m
# verbs >> verb
# diss >> dis
# ads >> ad
# ads >> ad
# ads >> ad
# checks >> check
# caps >> cap
# bonuses >> bonus
# levels >> level
# cards >> card
# instructions >> instruction
# cents >> cent
# hours >> hour
# days >> day
# leads >> lead
# seekers >> seeker
# groceries >> grocery
# vehicles >> vehicle
# appliances >> appliance
# items >> item
# us >> u
# addresses >> address
# less >> le
# profits >> profit
# less >> le
# addresses >> address
# specials >> special
# us >> u
# hours >> hour
# has >> ha
# has >> ha
# us >> u
# grounds >> ground
# grounds >> ground
# grounds >> ground
# supplies >> supply
# us >> u
# brits >> brit
# globes >> globe
# us >> u
# us >> u
# brits >> brit
# brits >> brit
# globes >> globe
# us >> u
# us >> u
# us >> u
# seconds >> second
# us >> u
# tours >> tour
# seconds >> second
# urls >> url
# less >> le
# ps >> p
# tas >> ta
# means >> mean
# us >> u
# shades >> shade
# senses >> sens
# qs >> q
# means >> mean
# discuss >> discus
# uses >> us
# vs >> v
# sounds >> sound
# us >> u
# lus >> lu
# mvs >> mv
# addresses >> address
# rights >> right
# rights >> right
# ways >> way
# names >> name
# hours >> hour
# sales >> sale
# rights >> right
# ovs >> ov
# bas >> ba
# bas >> ba
# bas >> ba
# papers >> paper
# speakers >> speaker
# directions >> direction
# languages >> language
# las >> la
# cruces >> crux
# speakers >> speaker
# arts >> art
# sciences >> science
# papers >> paper
# sns >> sn
# sns >> sn
# sns >> sn
# sns >> sn
# sns >> sn
# las >> la
# abstracts >> abstract
# papers >> paper
# speakers >> speaker
# papers >> paper
# papers >> paper
# papers >> paper
# papers >> paper
# las >> la
# finances >> finance
# us >> u
# enterprises >> enterprise
# discuss >> discus
# prospects >> prospect
# us >> u
# prospects >> prospect
# payments >> payment
# methods >> method
# us >> u
# us >> u
# us >> u
# us >> u
# us >> u
# turtles >> turtle
# offers >> offer
# us >> u
# us >> u
# sells >> sell
# participants >> participant
# us >> u
# us >> u
# us >> u
# services >> service
# services >> service
# services >> service
# us >> u
# us >> u
# services >> service
# us >> u
# years >> year
# years >> year
# services >> service
# companies >> company
# pass >> pas
# us >> u
# days >> day
# us >> u
# less >> le
# ps >> p
# discuss >> discus
# has >> ha
# has >> ha
# works >> work
# us >> u
# prices >> price
# programs >> program
# pass >> pas
# employees >> employee
# friends >> friend
# relatives >> relative
# neighbors >> neighbor
# boss >> bos
# urls >> url
# employees >> employee
# countries >> country
# tips >> tip
# uses >> us
# boss >> bos
# traps >> trap
# reputations >> reputation
# products >> product
# criminals >> criminal
# records >> record
# thousands >> thousand
# uses >> us
# secrets >> secret
# has >> ha
# does >> doe
# updates >> update
# sources >> source
# works >> work
# us >> u
# boss >> bos
# sources >> source
# windows >> window
# letters >> letter
# rights >> right
# friends >> friend
# ones >> one
# dads >> dad
# moms >> mom
# cards >> card
# ms >> m
# ms >> m
# ms >> m
# years >> year
# less >> le
# statistics >> statistic
# us >> u
# windows >> window
# less >> le
# pass >> pas
# us >> u
# instructions >> instruction
# benefits >> benefit
# problems >> problem
# hundreds >> hundred
# orders >> order
# reports >> report
# checks >> check
# reports >> report
# sales >> sale
# corporations >> corporation
# sales >> sale
# sources >> source
# lists >> list
# sales >> sale
# plans >> plan
# totals >> total
# tips >> tip
# orders >> order
# guidelines >> guideline
# ms >> m
# pass >> pas
# works >> work
# pass >> pas
# pass >> pas
# reports >> report
# yields >> yield
# results >> result
# pass >> pas
# instructions >> instruction
# benefits >> benefit
# hundreds >> hundred
# orders >> order
# reports >> report
# sales >> sale
# corporations >> corporation
# sales >> sale
# sources >> source
# lists >> list
# sales >> sale
# plans >> plan
# totals >> total
# tips >> tip
# orders >> order
# ms >> m
# pass >> pas
# reports >> report
# papers >> paper
# folks >> folk
# dates >> date
# contents >> content
# advances >> advance
# us >> u
# us >> u
# workings >> working
# highlights >> highlight
# sis >> si
# sis >> si
# contents >> content
# pass >> pas
# cs >> c
# aus >> au
# aus >> au
# leaders >> leader
# factors >> factor
# less >> le
# respects >> respect
# fees >> fee
# proceedings >> proceeding
# refreshments >> refreshment
# methods >> method
# us >> u
# us >> u
# us >> u
# us >> u
# proceedings >> proceeding
# chairs >> chair
# wus >> wu
# us >> u
# papers >> paper
# speakers >> speaker
# papers >> paper
# proceedings >> proceeding
# arts >> art
# humanities >> humanity
# qualifications >> qualification
# applications >> application
# papers >> paper
# coupons >> coupon
# savings >> saving
# discounts >> discount
# discounts >> discount
# goods >> good
# goods >> good
# less >> le
# savings >> saving
# goods >> good
# furnishings >> furnishing
# savings >> saving
# us >> u
# us >> u
# motors >> motor
# us >> u
# us >> u
# finances >> finance
# hundreds >> hundred
# us >> u
# employees >> employee
# friends >> friend
# relatives >> relative
# neighbors >> neighbor
# boss >> bos
# urls >> url
# employees >> employee
# countries >> country
# tips >> tip
# uses >> us
# boss >> bos
# traps >> trap
# reputations >> reputation
# products >> product
# criminals >> criminal
# records >> record
# thousands >> thousand
# uses >> us
# secrets >> secret
# has >> ha
# does >> doe
# updates >> update
# sources >> source
# works >> work
# us >> u
# boss >> bos
# sources >> source
# windows >> window
# rights >> right
# meetings >> meeting
# products >> product
# sponsors >> sponsor
# friends >> friend
# mailings >> mailing
# brochures >> brochure
# headaches >> headache
# hassles >> hassle
# papers >> paper
# articles >> article
# papers >> paper
# papers >> paper
# aims >> aim
# papers >> paper
# discuss >> discus
# papers >> paper
# papers >> paper
# papers >> paper
# papers >> paper
# details >> detail
# papers >> paper
# papers >> paper
# papers >> paper
# ps >> p
# papers >> paper
# editors >> editor
# details >> detail
# contents >> content
# pages >> page
# rights >> right
# regards >> regard
# us >> u
# rights >> right
# us >> u
# us >> u
# us >> u
# us >> u
# proceedings >> proceeding
# wales >> wale
# stamps >> stamp
# us >> u
# reviews >> review
# awards >> award
# lines >> line
# brits >> brit
# releases >> release
# reviews >> review
# brits >> brit
# brits >> brit
# us >> u
# lines >> line
# brits >> brit
# brits >> brit
# releases >> release
# djs >> dj
# engines >> engine
# mrds >> mrd
# mrds >> mrd
# senses >> sens
# mrds >> mrd
# roma >> rom
# roma >> rom
# roma >> rom
# roma >> rom
# roma >> rom
# roma >> rom
# guidelines >> guideline
# copies >> copy
# roma >> rom
# pages >> page
# files >> file
# keys >> key
# dates >> date
# roma >> rom
# us >> u
# us >> u
# dollars >> dollar
# us >> u
# papers >> paper
# papers >> paper
# discuss >> discus
# papers >> paper
# papers >> paper
# discuss >> discus
# discuss >> discus
# us >> u
# contents >> content
# us >> u
# us >> u
# us >> u
# us >> u
# papers >> paper
# papers >> paper
# papers >> paper
# papers >> paper
# papers >> paper
# papers >> paper
# abstracts >> abstract
# requirements >> requirement
# abstracts >> abstract
# fees >> fee
# us >> u
# us >> u
# us >> u
# us >> u
# us >> u
# us >> u
# das >> da
# das >> da
# das >> da
# sales >> sale
# costs >> cost
# pass >> pas
# boss >> bos
# individuals >> individual
# applicants >> applicant
# compliments >> compliment
# dss >> ds
# days >> day
# plans >> plan
# bonuses >> bonus
# comes >> come
# bonuses >> bonus
# orders >> order
# less >> le
# papers >> paper
# less >> le
# grammars >> grammar
# us >> u
# us >> u
# us >> u
# umass >> uma
# umass >> uma
# discuss >> discus
# discuss >> discus
# piers >> pier
# piers >> pier
# means >> mean
# piers >> pier
# piers >> pier
# piers >> pier
# us >> u
# plurals >> plural
# does >> doe
# possess >> posse
# wus >> wu
# us >> u
# nos >> no
# nus >> nu
# nus >> nu
# papers >> paper
# papers >> paper
# proceedings >> proceeding
# papers >> paper
# thousands >> thousand
# thousands >> thousand
# helps >> help
# pass >> pas
# pass >> pas
# pass >> pas
# rights >> right
# us >> u
# us >> u
# seconds >> second
# reviews >> review
# women >> woman
# picks >> pick
# cds >> cd
# reviews >> review
# us >> u
# women >> woman
# women >> woman
# picks >> pick
# singles >> single
# vibes >> vibe
# las >> la
# hindus >> hindu
# hindus >> hindu
# us >> u
# papers >> paper
# pass >> pas
# pass >> pas
# pass >> pas
# pass >> pas
# pass >> pas
# discuss >> discus
# means >> mean
# pass >> pas
# us >> u
# volumes >> volume
# contents >> content
# contexts >> context
# volumes >> volume
# contents >> content
# chous >> chou
# resources >> resource
# papers >> paper
# us >> u
# discuss >> discus
# proceedings >> proceeding
# shields >> shield
# papers >> paper
# corpora >> corpus
# papers >> paper
# means >> mean
# restrictions >> restriction
# submissions >> submission
# conditions >> condition
# papers >> paper
# means >> mean
# submissions >> submission
# papers >> paper
# proceedings >> proceeding
# addresses >> address
# dates >> date
# millions >> million
# rights >> right
# winners >> winner
# rights >> right
# pass >> pas
# us >> u
# us >> u
# us >> u
# rights >> right
# languages >> language
# sessions >> session
# sessions >> session
# phenomena >> phenomenon
# gess >> ge
# dps >> dp
# nus >> nu
# nus >> nu
# gess >> ge
# discuss >> discus
# means >> mean
# papers >> paper
# pes >> pe
# us >> u
# us >> u
# communications >> communication
# sous >> sou
# gates >> gate
# pass >> pas
# instructions >> instruction
# benefits >> benefit
# hundreds >> hundred
# rates >> rate
# orders >> order
# reports >> report
# sales >> sale
# corporations >> corporation
# sales >> sale
# mas >> ma
# sources >> source
# lists >> list
# sales >> sale
# plans >> plan
# totals >> total
# tips >> tip
# orders >> order
# ms >> m
# pass >> pas
# works >> work
# pass >> pas
# pass >> pas
# reports >> report
# boss >> bos
# goods >> good
# fees >> fee
# fees >> fee
# pass >> pas
# us >> u
# contents >> content
# lunches >> lunch
# folks >> folk
# less >> le
# cents >> cent
# us >> u
# us >> u
# us >> u
# us >> u
# cds >> cd
# comes >> come
# friends >> friend
# details >> detail
# works >> work
# pass >> pas
# us >> u
# aus >> au
# pass >> pas
# means >> mean
# means >> mean
# facts >> fact
# writings >> writing
# pass >> pas
# was >> wa
# has >> ha
# results >> result
# weeks >> week
# less >> le
# days >> day
# developments >> development
# developments >> development
# media >> medium
# speakers >> speaker
# colloquia >> colloquium
# developments >> development
# developments >> development
# frames >> frame
# sessions >> session
# influences >> influence
# categories >> category
# structures >> structure
# hindus >> hindu
# enactments >> enactment
# ideologies >> ideology
# identities >> identity
# approaches >> approach
# discourses >> discourse
# faces >> face
# moves >> move
# explanations >> explanation
# patterns >> pattern
# views >> view
# media >> medium
# structures >> structure
# languages >> language
# discourses >> discourse
# conferences >> conference
# pragmatics >> pragmatic
# papers >> paper
# papers >> paper
# papers >> paper
# submissions >> submission
# papers >> paper
# papers >> paper
# us >> u
# us >> u
# ms >> m
# us >> u
# papers >> paper
# topics >> topic
# topics >> topic
# discuss >> discus
# papers >> paper
# provinces >> province
# papers >> paper
# abstracts >> abstract
# dues >> due
# us >> u
# analysts >> analyst
# returns >> return
# shares >> share
# turtles >> turtle
# offers >> offer
# us >> u
# us >> u
# papers >> paper
# proceedings >> proceeding
# replies >> reply
# us >> u
# was >> wa
# less >> le
# less >> le
# orders >> order
# weeks >> week
# programs >> program
# orders >> order
# weeks >> week
# programs >> program
# orders >> order
# works >> work
# ps >> p
# pass >> pas
# us >> u
# dollars >> dollar
# us >> u
# works >> work
# programs >> program
# goods >> good
# us >> u
# statistics >> statistic
# instructions >> instruction
# works >> work
# orders >> order
# reports >> report
# reports >> report
# positions >> position
# reports >> report
# orders >> order
# reports >> report
# sales >> sale
# corporations >> corporation
# sales >> sale
# sources >> source
# lists >> list
# sales >> sale
# plans >> plan
# steps >> step
# papers >> paper
# papers >> paper
# faies >> fay
# papers >> paper
# smokers >> smoker
# days >> day
# boss >> bos
# us >> u
# tons >> ton
# boys >> boy
# cardigans >> cardigan
# antics >> antic
# boys >> boy
# cardigans >> cardigan
# us >> u
# has >> ha
# less >> le
# less >> le
# works >> work
# less >> le
# means >> mean
# urls >> url
# has >> ha
# cards >> card
# us >> u
# notes >> note
# less >> le
# less >> le
# bbs >> bb
# less >> le
# bbs >> bb
# angels >> angel
# secrets >> secret
# angels >> angel
# secrets >> secret
# angels >> angel
# secrets >> secret
# angels >> angel
# means >> mean
# us >> u
# volumes >> volume
# less >> le
# discuss >> discus
# papers >> paper
# discuss >> discus
# papers >> paper
# papers >> paper
# proceedings >> proceeding
# proceedings >> proceeding
# papers >> paper
# papers >> paper
# papers >> paper
# proceedings >> proceeding
# cranberries >> cranberry
# djs >> dj
# cranberries >> cranberry
# singles >> single
# singles >> single
# djs >> dj
# shares >> share
# pass >> pas
# instructions >> instruction
# benefits >> benefit
# hundreds >> hundred
# orders >> order
# reports >> report
# sales >> sale
# corporations >> corporation
# sales >> sale
# sources >> source
# lists >> list
# sales >> sale
# plans >> plan
# totals >> total
# tips >> tip
# orders >> order
# ms >> m
# pass >> pas
# reports >> report
# us >> u
# supplies >> supply
# supplies >> supply
# boss >> bos
# folks >> folk
# works >> work
# supplies >> supply
# works >> work
# supplies >> supply
# us >> u
# us >> u
# us >> u
# mailers >> mailer
# mailers >> mailer
# returns >> return
# discuss >> discus
# means >> mean
# us >> u
# nps >> np
# us >> u
# tells >> tell
# discuss >> discus
# discuss >> discus
# tls >> tl
# gess >> ge
# has >> ha
# children >> child
# less >> le
# basics >> basic
# us >> u
# us >> u
# papers >> paper
# papers >> paper
# releases >> release
# releases >> release
# cds >> cd
# less >> le
# less >> le
# orders >> order
# weeks >> week
# programs >> program
# orders >> order
# weeks >> week
# programs >> program
# orders >> order
# works >> work
# ps >> p
# pass >> pas
# us >> u
# dollars >> dollar
# us >> u
# works >> work
# programs >> program
# goods >> good
# us >> u
# statistics >> statistic
# instructions >> instruction
# works >> work
# orders >> order
# reports >> report
# reports >> report
# positions >> position
# reports >> report
# orders >> order
# reports >> report
# sales >> sale
# corporations >> corporation
# sales >> sale
# sources >> source
# lists >> list
# sales >> sale
# plans >> plan
# steps >> step
# studies >> study
# us >> u
# papers >> paper
# us >> u
# homeowners >> homeowner
# bills >> bill
# improvements >> improvement
# thousands >> thousand
# payments >> payment
# options >> option
# us >> u
# us >> u
# us >> u
# addresses >> address
# us >> u
# us >> u
# us >> u
# us >> u
# us >> u
# us >> u
# services >> service
# bbs >> bb
# us >> u
# us >> u
# systems >> system
# systems >> system
# resources >> resource
# aims >> aim
# discuss >> discus
# pages >> page
# keys >> key
# dates >> date
# papers >> paper
# us >> u
# us >> u
# us >> u
# us >> u
# us >> u
# us >> u
# us >> u
# skills >> skill
# does >> doe
# has >> ha
# us >> u
# us >> u
# papers >> paper
# papers >> paper
# proceedings >> proceeding
# papers >> paper
# papers >> paper
# proceedings >> proceeding
# less >> le
# grounds >> ground
# discuss >> discus
# savings >> saving
# prospects >> prospect
# prospects >> prospect
# prospects >> prospect
# us >> u
# discuss >> discus
# supplies >> supply
# contents >> content
# us >> u
# us >> u
# das >> da
# papers >> paper
# methods >> method
# statistics >> statistic
# papers >> paper
# statistics >> statistic
# discuss >> discus
# species >> specie
# idioms >> idiom
# us >> u
# discuss >> discus
# less >> le
# us >> u
# shares >> share
# specials >> special
# ms >> m
# media >> medium
# media >> medium
# media >> medium
# media >> medium
# media >> medium
# media >> medium
# media >> medium
# media >> medium
# media >> medium
# us >> u
# means >> mean
# dollars >> dollar
# us >> u
# us >> u
# us >> u
# us >> u
# us >> u
# us >> u
# exceptions >> exception
# us >> u
# hills >> hill
# us >> u
# phenomena >> phenomenon
# thousands >> thousand
# messages >> message
# messages >> message
# messages >> message
# millions >> million
# addresses >> address
# programs >> program
# rights >> right
# customers >> customer
# letters >> letter
# thousands >> thousand
# windows >> window
# less >> le
# less >> le
# limits >> limit
# supports >> support
# formats >> format
# files >> file
# speeds >> speed
# connections >> connection
# amounts >> amount
# mailings >> mailing
# amounts >> amount
# orders >> order
# names >> name
# mailings >> mailing
# orders >> order
# millions >> million
# addresses >> address
# millions >> million
# millions >> million
# addresses >> address
# millions >> million
# millions >> million
# millions >> million
# addresses >> address
# millions >> million
# rights >> right
# reports >> report
# plans >> plan
# secrets >> secret
# thousands >> thousand
# checks >> check
# us >> u
# us >> u
# requirements >> requirement
# notes >> note
# users >> user
# cis >> ci
# needless >> needle
# needless >> needle
# ks >> k
# millions >> million
# millions >> million
# checks >> check
# numbers >> number
# numbers >> number
# addresses >> address
# us >> u
# us >> u
# less >> le
# profits >> profit
# less >> le
# addresses >> address
# specials >> special
# us >> u
# questions >> question
# us >> u
# grounds >> ground
# grounds >> ground
# prospects >> prospect
# species >> specie
# pcs >> pc
# meetings >> meeting
# calls >> call
# calls >> call
# quotas >> quota
# friends >> friend
# relatives >> relative
# calls >> call
# questions >> question
# sales >> sale
# hrs >> hr
# messages >> message
# papers >> paper
# papers >> paper
# services >> service
# us >> u
# friends >> friend
# pass >> pas
# jerks >> jerk
# works >> work
# addresses >> address
# donations >> donation
# us >> u
# us >> u
# us >> u
# cus >> cu
# us >> u
# papers >> paper
# papers >> paper
# volumes >> volume
# papers >> paper
# taus >> tau
# papers >> paper
# us >> u
# taus >> tau
# discuss >> discus
# taus >> tau
# taus >> tau
# discuss >> discus
# taus >> tau
# discuss >> discus
# discuss >> discus
# taus >> tau
# taus >> tau
# taus >> tau
# taus >> tau
# discuss >> discus
# taus >> tau
# discuss >> discus
# taus >> tau
# volumes >> volume
# papers >> paper
# taus >> tau
# aspects >> aspect
# papers >> paper
# papers >> paper
# papers >> paper
# papers >> paper
# us >> u
# studies >> study
# resources >> resource
# papers >> paper
# us >> u
# discuss >> discus
# workshops >> workshop
# proceedings >> proceeding
# refreshments >> refreshment
# proceedings >> proceeding
# proceedings >> proceeding
# forms >> form
# resources >> resource
# fees >> fee
# proceedings >> proceeding
# refreshments >> refreshment
# us >> u
# addresses >> address
# statistics >> statistic
# statistics >> statistic
# roma >> rom
# means >> mean
# assess >> ass
# pos >> po
# papers >> paper
# roma >> rom
# nederlands >> nederland
# roma >> rom
# roma >> rom
# roma >> rom
# pages >> page
# files >> file
# keys >> key
# roma >> rom
# roma >> rom
# contents >> content
# us >> u
# us >> u
# pass >> pas
# us >> u
# has >> ha
# us >> u
# papers >> paper
# discuss >> discus
# us >> u
# discuss >> discus
# papers >> paper
# gis >> gi
# papers >> paper
# papers >> paper
# papers >> paper
# papers >> paper
# papers >> paper
# us >> u
# ms >> m
# papers >> paper
# papers >> paper
# panels >> panel
# tutorials >> tutorial
# demos >> demo
# pass >> pas
# pass >> pas
# means >> mean
# hindus >> hindu
# less >> le
# pass >> pas
# rights >> right
# media >> medium
# troops >> troop
# media >> medium
# prospects >> prospect
# als >> al
# us >> u
# lees >> lee
# als >> al
# lees >> lee
# us >> u
# corpora >> corpus
# us >> u
# linguists >> linguist
# us >> u
# auspices >> auspex
# proceedings >> proceeding
# lectures >> lecture
# tours >> tour
# tours >> tour
# tours >> tour
# proceedings >> proceeding
# proceedings >> proceeding
# less >> le
# days >> day
# secrets >> secret
# secrets >> secret
# bureaus >> bureau
# bureaus >> bureau
# cards >> card
# loans >> loan
# loans >> loan
# loans >> loan
# days >> day
# less >> le
# profits >> profit
# ss >> s
# addresses >> address
# specials >> special
# us >> u
# hours >> hour
# papers >> paper
# papers >> paper
# proceedings >> proceeding
# papers >> paper
# proceedings >> proceeding
# abstracts >> abstract
# less >> le
# questions >> question
# ads >> ad
# us >> u
# problems >> problem
# pcs >> pc
# us >> u
# us >> u
# less >> le
# us >> u
# saints >> saint
# months >> month
# us >> u
# us >> u
# requests >> request
# contents >> content
# women >> woman
# women >> woman
# women >> woman
# women >> woman
# women >> woman
# credentials >> credential
# women >> woman
# thousands >> thousand
# messages >> message
# messages >> message
# messages >> message
# millions >> million
# addresses >> address
# programs >> program
# letters >> letter
# thousands >> thousand
# windows >> window
# less >> le
# less >> le
# limits >> limit
# supports >> support
# formats >> format
# files >> file
# speeds >> speed
# connections >> connection
# amounts >> amount
# mailings >> mailing
# amounts >> amount
# orders >> order
# names >> name
# mailings >> mailing
# orders >> order
# millions >> million
# addresses >> address
# millions >> million
# millions >> million
# addresses >> address
# millions >> million
# millions >> million
# millions >> million
# addresses >> address
# millions >> million
# rights >> right
# reports >> report
# plans >> plan
# secrets >> secret
# thousands >> thousand
# checks >> check
# us >> u
# us >> u
# requirements >> requirement
# notes >> note
# users >> user
# cis >> ci
# needless >> needle
# needless >> needle
# ks >> k
# millions >> million
# millions >> million
# checks >> check
# numbers >> number
# numbers >> number
# addresses >> address
# us >> u
# us >> u
# ladies >> lady
# us >> u
# pass >> pas
# us >> u
# us >> u
# papers >> paper
# us >> u
# supplies >> supply
# supplies >> supply
# boss >> bos
# folks >> folk
# works >> work
# supplies >> supply
# works >> work
# supplies >> supply
# us >> u
# us >> u
# us >> u
# mailers >> mailer
# mailers >> mailer
# less >> le
# wus >> wu
# discuss >> discus
# seconds >> second
# urls >> url
# less >> le
# us >> u
# ems >> em
# ems >> em
# ems >> em
# ems >> em
# ems >> em
# ems >> em
# ems >> em
# ems >> em
# ems >> em
# ems >> em
# ems >> em
# us >> u
# millions >> million
# roms >> rom
# us >> u
# supplies >> supply
# us >> u
# assess >> ass
# particulars >> particular
# languages >> language
# us >> u
# refreshments >> refreshment
# less >> le
# programs >> program
# congratulations >> congratulation
# adults >> adult
# children >> child
# adults >> adult
# pass >> pas
# hundreds >> hundred
# dollars >> dollar
# discounts >> discount
# tickets >> ticket
# days >> day
# nights >> night
# days >> day
# nights >> night
# incidentals >> incidental
# means >> mean
# sitas >> sita
# papers >> paper
# papers >> paper
# papers >> paper
# us >> u
# us >> u
# aims >> aim
# papers >> paper
# less >> le
# queries >> query
# less >> le
# papers >> paper
# papers >> paper
# papers >> paper
# papers >> paper
# papers >> paper
# papers >> paper
# papers >> paper
# papers >> paper
# us >> u
# proceedings >> proceeding
# papers >> paper
# linguists >> linguist
# colloquia >> colloquium
# discuss >> discus
# details >> detail
# papers >> paper
# papers >> paper
# papers >> paper
# proposals >> proposal
# papers >> paper
# costs >> cost
# scholarships >> scholarship
# papers >> paper
# papers >> paper
# ms >> m
# pass >> pas
# less >> le
# factors >> factor
# texts >> text
# us >> u
# proceedings >> proceeding
# refreshments >> refreshment
# factors >> factor
# texts >> text
# us >> u
# us >> u
# organisers >> organiser
# ms >> m
# papers >> paper
# us >> u
# prospects >> prospect
# us >> u
# means >> mean
# less >> le
# has >> ha
# pass >> pas
# us >> u
# secrets >> secret
# folks >> folk
# means >> mean
# possibilities >> possibility
# boss >> bos
# less >> le
# days >> day
# papers >> paper
# addresses >> address
# bonuses >> bonus
# less >> le
# discuss >> discus
# kanzus >> kanzu
# kanzus >> kanzu
# kanzus >> kanzu
# kanzus >> kanzu
# papers >> paper
# leass >> lea
# specifics >> specific
# papers >> paper
# papers >> paper
# lines >> line
# depths >> depth
# lines >> line
# goods >> good
# us >> u
# ass >> as
# contents >> content
# dudes >> dude
# us >> u
# discuss >> discus
# less >> le
# less >> le
# orders >> order
# weeks >> week
# programs >> program
# orders >> order
# weeks >> week
# programs >> program
# orders >> order
# works >> work
# pass >> pas
# benefits >> benefit
# hundreds >> hundred
# orders >> order
# reports >> report
# sales >> sale
# corporations >> corporation
# sales >> sale
# sources >> source
# sales >> sale
# plans >> plan
# totals >> total
# tips >> tip
# pass >> pas
# works >> work
# pass >> pas
# pass >> pas
# reports >> report
# women >> woman
# women >> woman
# women >> woman
# aspects >> aspect
# women >> woman
# rules >> rule
# interactions >> interaction
# us >> u
# us >> u
# us >> u
# us >> u
# papers >> paper
# papers >> paper
# species >> specie
# statistics >> statistic
# assess >> ass
# papers >> paper
# papers >> paper
# papers >> paper
# papers >> paper
# dates >> date
# papers >> paper
# discussions >> discussion
# discuss >> discus
# tutorials >> tutorial
# statistics >> statistic
# demonstrations >> demonstration
# ras >> ra
# less >> le
# orders >> order
# weeks >> week
# programs >> program
# orders >> order
# weeks >> week
# programs >> program
# orders >> order
# works >> work
# pass >> pas
# instructions >> instruction
# benefits >> benefit
# works >> work
# hundreds >> hundred
# pass >> pas
# orders >> order
# reports >> report
# sales >> sale
# us >> u
# corporations >> corporation
# sales >> sale
# sources >> source
# lists >> list
# sales >> sale
# plans >> plan
# totals >> total
# tips >> tip
# orders >> order
# ms >> m
# pass >> pas
# works >> work
# pass >> pas
# pass >> pas
# reports >> report
# cousins >> cousin
# cds >> cd
# cousins >> cousin
# las >> la
# millions >> million
# us >> u
# addresses >> address
# lists >> list
# cds >> cd
# means >> mean
# less >> le
# prospects >> prospect
# less >> le
# less >> le
# volumes >> volume
# us >> u
# pass >> pas
# millions >> million
# us >> u
# millions >> million
# millions >> million
# us >> u
# us >> u
# numbers >> number
# numbers >> number
# us >> u
# services >> service
# services >> service
# us >> u
# mvs >> mv
# less >> le
# less >> le
# children >> child
# us >> u
# capitals >> capital
# peters >> peter
# hindus >> hindu
# papers >> paper
# aims >> aim
# papers >> paper
# papers >> paper
# papers >> paper
# media >> medium
# papers >> paper
# proceedings >> proceeding
# us >> u
# erss >> er
# papers >> paper
# motivations >> motivation
# topics >> topic
# discuss >> discus
# physics >> physic
# speakers >> speaker
# papers >> paper
# erss >> er
# erss >> er
# architectures >> architecture
# mechanisms >> mechanism
# speakers >> speaker
# sponsors >> sponsor
# universities >> university
# us >> u
# bbs >> bb
# less >> le
# problems >> problem
# problems >> problem
# boss >> bos
# gass >> gas
# gass >> gas
# gass >> gas
# us >> u
# us >> u
# papers >> paper
# hindus >> hindu
# results >> result
# statistics >> statistic
# savings >> saving
# us >> u
# adults >> adult
# children >> child
# adults >> adult
# pass >> pas
# hundreds >> hundred
# dollars >> dollar
# discounts >> discount
# tickets >> ticket
# days >> day
# nights >> night
# days >> day
# nights >> night
# incidentals >> incidental
# millions >> million
# us >> u
# addresses >> address
# lists >> list
# cds >> cd
# means >> mean
# less >> le
# prospects >> prospect
# less >> le
# less >> le
# volumes >> volume
# us >> u
# pass >> pas
# millions >> million
# us >> u
# millions >> million
# millions >> million
# us >> u
# us >> u
# numbers >> number
# numbers >> number
# us >> u
# services >> service
# services >> service
# us >> u
# returns >> return
# papers >> paper
# dgs >> dg
# dgs >> dg
# dgs >> dg
# papers >> paper
# dgs >> dg
# dgs >> dg
# dgs >> dg
# us >> u
# programs >> program
# papers >> paper
# papers >> paper
# moos >> moo
# papers >> paper
# papers >> paper
# strides >> stride
# strides >> stride
# pass >> pas
# us >> u
# kas >> ka
# advances >> advance
# icus >> icu
# icus >> icu
# aus >> au
# advances >> advance
# topics >> topic
# papers >> paper
# chous >> chou
# speakers >> speaker
# media >> medium
# papers >> paper
# papers >> paper
# pcs >> pc
# events >> event
# participants >> participant
# companies >> company
# us >> u
# openings >> opening
# possess >> posse
# thousands >> thousand
# messages >> message
# messages >> message
# messages >> message
# addresses >> address
# programs >> program
# letters >> letter
# thousands >> thousand
# windows >> window
# less >> le
# less >> le
# limits >> limit
# supports >> support
# formats >> format
# files >> file
# speeds >> speed
# connections >> connection
# amounts >> amount
# mailings >> mailing
# amounts >> amount
# orders >> order
# names >> name
# mailings >> mailing
# orders >> order
# addresses >> address
# millions >> million
# millions >> million
# addresses >> address
# millions >> million
# millions >> million
# millions >> million
# addresses >> address
# millions >> million
# rights >> right
# reports >> report
# plans >> plan
# secrets >> secret
# thousands >> thousand
# checks >> check
# us >> u
# us >> u
# requirements >> requirement
# notes >> note
# users >> user
# cis >> ci
# needless >> needle
# needless >> needle
# ks >> k
# millions >> million
# millions >> million
# checks >> check
# numbers >> number
# numbers >> number
# addresses >> address
# us >> u
# us >> u
# grounds >> ground
# standards >> standard
# achievements >> achievement
# assessments >> assessment
# ms >> m
# ps >> p
# assess >> ass
# assess >> ass
# papers >> paper
# lists >> list
# individuals >> individual
# us >> u
# us >> u
# regards >> regard
# qs >> q
# papers >> paper
# savings >> saving
# profits >> profit
# us >> u
# details >> detail
# valentines >> valentine
# awards >> award
# movies >> movie
# books >> book
# valentines >> valentine
# awards >> award
# fess >> fes
# movies >> movie
# books >> book
# reports >> report
# seconds >> second
# us >> u
# weiss >> wei
# weiss >> wei
# grounds >> ground
# grounds >> ground
# papers >> paper
# means >> mean
# umass >> uma
# cis >> ci
# cs >> c
# us >> u
# classics >> classic
# publications >> publication
# classics >> classic
# brothers >> brother
# films >> film
# us >> u
# papers >> paper
# papers >> paper
# us >> u
# papers >> paper
# papers >> paper
# less >> le
# goods >> good
# statistics >> statistic
# less >> le
# orders >> order
# weeks >> week
# programs >> program
# orders >> order
# weeks >> week
# programs >> program
# orders >> order
# works >> work
# us >> u
# dollars >> dollar
# works >> work
# programs >> program
# instructions >> instruction
# works >> work
# orders >> order
# reports >> report
# reports >> report
# positions >> position
# reports >> report
# orders >> order
# reports >> report
# sales >> sale
# corporations >> corporation
# sales >> sale
# sources >> source
# lists >> list
# sales >> sale
# plans >> plan
# steps >> step
# reports >> report
# reports >> report
# rights >> right
# reports >> report
# reports >> report
# papers >> paper
# contents >> content
# phenomena >> phenomenon
# phenomena >> phenomenon
# instructions >> instruction
# instructions >> instruction
# addresses >> address
# programs >> program
# us >> u
# papers >> paper
# papers >> paper
# us >> u
# us >> u
# us >> u
# us >> u
# pass >> pas
# us >> u
# us >> u
# us >> u
# less >> le
# us >> u
# titles >> title
# benjamins >> benjamin
# papers >> paper
# us >> u
# us >> u
# papers >> paper
# papers >> paper
# discuss >> discus
# us >> u
# us >> u
# discuss >> discus
# us >> u
# us >> u
# us >> u
# us >> u
# papers >> paper
# papers >> paper
# us >> u
# us >> u
# papers >> paper
# discuss >> discus
# papers >> paper
# pragmatics >> pragmatic
# developments >> development
# us >> u
# us >> u
# papers >> paper
# papers >> paper
# papers >> paper
# papers >> paper
# etymologies >> etymology
# observations >> observation
# us >> u
# us >> u
# done
# Subject: wkshp : * early * - e ( = ) uralic interaction
#
# organize combination colloquium work seminar plan place oulu finland after jyvaskylum 8th internat ' l fenno - ugric congress ( fu8 run thru 15 august ' 95 ) . entitle " ( s ) north , " gather intend convoke roughly 30-40 scholar discuss archaeological , bioanthropological , ethnographic ( include comparative myth / religion / folkway etc ) , * linguistic * datum , concept , method inter-relate bear question development sundry scandinavium , fenno - karelium , northwest russium , northern circum - ural . gather aid idea exchange among specialist domain pertinent reconstruction ( pre ) historical event process involve ( s ) region . those each speciality require speak ignorance , . e . , prepare discuss * * already , point really * * those speciality . aim avoid presentation set-piece foment exploration many possible each various ( pre ) historical discipline feed . collaborator venture ( norbert strade , historically archaeologically incline linguist , aarhus dk ; milton nunez , ethnologically geographically incline archaeologist oulu ) long list probable participant . however , feel distinct under - representation regards indo - europeanist linguistics . those - eist our acquaintance interest pre - - e substrate effect northern europe , possible early - e f - u interaction north ( elsewhere ) , intrigue theme relevance our plan , cannot oulu august . thus send request . anyone interest , please contact . nb - frame us begin repopulation north ice age retreat , hence less 10 , 000bp . discussion - e ( = ) uralic interaction / relation ground posit macro-family &c root ` deep ' therefore fall outside scope our plan . hope hear . ken jacob voice : ( 514 ) 343-6490 [ office ] assoc . prof . ( 514 ) 685-2349 [ home ] departement d ' anthropologie fax : ( 514 ) 343-2494 universite de montreal e-mail : jacobsk @ ere . umontreal . ca cp 6128 / succ . centre - ville montreal pq h3c 3j7 canada
#
# Subject wkshp early e uralic interaction organize combination colloquium work seminar plan place oulu finland after jyvaskylum 8th internat l fenno ugric congress fu8 run thru 15 august 95 entitle s north gather intend convoke roughly 3040 scholar discus archaeological bioanthropological ethnographic include comparative myth religion folkway etc linguistic datum concept method interrelate bear question development sundry scandinavium fenno karelium northwest russium northern circum ural gather aid idea exchange among specialist domain pertinent reconstruction pre historical event process involve s region those each speciality require speak ignorance e prepare discus already point really those speciality aim avoid presentation setpiece foment exploration many possible each various pre historical discipline feed collaborator venture norbert strade historically archaeologically incline linguist aarhus dk milton nunez ethnologically geographically incline archaeologist oulu long list probable participant however feel distinct under representation regard indo europeanist linguistics those eist our acquaintance interest pre e substrate effect northern europe possible early e f u interaction north elsewhere intrigue theme relevance our plan can not oulu august thus send request anyone interest please contact nb frame u begin repopulation north ice age retreat hence le 10 000bp discussion e uralic interaction relation ground posit macrofamily c root deep therefore fall outside scope our plan hope hear ken jacob voice 514 3436490 office assoc prof 514 6852349 home departement d anthropologie fax 514 3432494 universite de montreal email jacobsk ere umontreal ca cp 6128 succ centre ville montreal pq h3c 3j7 canada

# %% [markdown]
# - To visualize what words are most commonly occuring in this dataset, I created a word cloud. The larger the word, the more often it appears.
# - The word cloud below is for all emails in the dataset

# %%
from wordcloud import WordCloud

text = dataframe_train["ContentCleaned"].str.cat(sep='\n') #combine EVERY SINGLE ROW OF TEXT into A SINGLE STRING.....
# print(text[:10000]) #just checking that it works lol

wordcloud = WordCloud(width=1600, height=800, random_state=42).generate(text) #make the word cloud with a high resolution to see lots of detail
plt.figure(figsize=(10,5)) #increase size of image
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# - The word cloud that looks through all types of email doesn't really provide any useful insight into patterns that emerge in specific types of email, so now I'll make a word cloud for each specific type of email: spam and ham.

# %% [markdown]
# ### Spam:

# %%
spam_dataframe = dataframe_train[dataframe_train.Spam == True]
text = spam_dataframe["ContentCleaned"].str.cat(sep='\n') #combine EVERY SINGLE ROW OF TEXT into A SINGLE STRING.....
# print(text[:10000]) #just checking that it works lol

spam_wordcloud = WordCloud(width=1600, height=800, random_state=42).generate(text) #make the word cloud with a high resolution to see lots of detail
plt.figure(figsize=(10,5)) #increase size of image
plt.imshow(spam_wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ### Ham:

# %%
ham_dataframe = dataframe_train[dataframe_train.Spam == False]
text = ham_dataframe["ContentCleaned"].str.cat(sep='\n') #combine EVERY SINGLE ROW OF TEXT into A SINGLE STRING.....
# print(text[:10000]) #just checking that it works lol

ham_wordcloud = WordCloud(width=1600, height=800, random_state=42).generate(text) #make the word cloud with a high resolution to see lots of detail
plt.figure(figsize=(10,5)) #increase size of image
plt.imshow(ham_wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# - After creating

# %% [markdown]
# # 4. Prepare the Data
# - Lots of data prep was done in steps 2 and 3 due to the nature of the given data, so I will describe each of the data cleaning steps in more detail here.
# - First, a test train split was made because in a real world scenario, you wouldn't be given clean input data and part of your deployment is that you would need to clean inputted data first, so I create a test train split early to ensure the test data stays messy so that once I create the deployment version of my model, it will need to clean any inputted test data as it would need to in a real scenario.
# - Next, I clean the contents of the emails themselves. I first remove all the punctuations, then lemmatize every word to ensure that there are as many similar words to each other as possible, which helps with data visualization as well as model accuracy. Also as a result of doing this process, the spaces between words becomes consistent.
# - Finally, once this transformation is done, I make a new column with the cleaned version of the data. There isn't too much of a reason to keep the old data, but in most practices you would keep it anyway, so it doesn't really matter.

# %% [markdown]
# # 5. Model the data
# #### Models that I will try:
# - Logistic regression
# - Random forest regressor (rounding)
# - Linear SVR (rounding)
# #### The reason why I have resorted to rounding numerical models is because the data has like zero correlation so at this point its moreso just which one is luckier lmao
# #### An issue I have is that since I couldn't find any correlations between any of the different attributes, I have no easy way to show how well the data fits since it doesn't really act straightforward for anything... I'm just using age because it seems to be the best despite having no real correlation ¯\\\_(ツ)\_/¯

# %% [markdown]
# #### Linear regression:

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error #root of the average of the square of all differences
from sklearn.metrics import mean_absolute_error #all differences have equal weight (average without square)

lrg_model = LinearRegression()
lrg_model.fit(X_train,Y_train) #train model on test features (fitting the model)
lrg_purchased_predictions = lrg_model.predict(X_test)

#checks the predictions against the actual values
print('Mean Squared Error: ', mean_squared_error(Y_test, lrg_purchased_predictions, squared=False)) #~112k
print('Mean Absolute Error: ', mean_absolute_error(Y_test, lrg_purchased_predictions)) #~78k


plt.scatter(X_test.loc[:,"Age"], Y_test, color='darkorange',
            label='data',s=7)
plt.scatter(X_test.loc[:,"Age"], lrg_purchased_predictions, color='cornflowerblue',
         label='prediction',s=7)
plt.legend()
plt.show()


#that was just to show without rounding, heres the rounded version of the data
lrg_purchased_predictions_rounded = lrg_purchased_predictions.round(0)
print('Mean Squared Error: ', mean_squared_error(Y_test, lrg_purchased_predictions_rounded, squared=False))
print('Mean Absolute Error: ', mean_absolute_error(Y_test, lrg_purchased_predictions_rounded))

plt.scatter(X_test.loc[:,"Age"], Y_test, color='darkorange',
            label='data',s=7)
plt.scatter(X_test.loc[:,"Age"], lrg_purchased_predictions_rounded, color='cornflowerblue',
         label='prediction',s=7)
plt.legend()
plt.show()
#side note, every single value rounded to 0 which I think is really funny
# Out:
# Mean Squared Error:  0.5999385873906532
# Mean Absolute Error:  0.5446020776078934
# Mean Squared Error:  0.701209207126852
# Mean Absolute Error:  0.49169435215946844

# %% [markdown]
# #### Random forest regressor:

# %%
from sklearn.ensemble import RandomForestRegressor
 
rfr_model = RandomForestRegressor(n_estimators=100,random_state=0)
rfr_model.fit(X_train, Y_train)
rfr_purchased_predictions = rfr_model.predict(X_test)

print('Mean Squared Error: ', mean_squared_error(Y_test, rfr_purchased_predictions, squared=False))
print('Mean Absolute Error: ', mean_absolute_error(Y_test, rfr_purchased_predictions))


plt.scatter(X_test.loc[:,"Age"], Y_test, color='darkorange',
            label='data',s=7)
plt.scatter(X_test.loc[:,"Age"], rfr_purchased_predictions, color='cornflowerblue',
         label='prediction',s=7)
plt.legend()
plt.show()


#that was just to show without rounding, heres the rounded version of the data
rfr_purchased_predictions_rounded = rfr_purchased_predictions.round(0)
print('Mean Squared Error: ', mean_squared_error(Y_test, rfr_purchased_predictions_rounded, squared=False))
print('Mean Absolute Error: ', mean_absolute_error(Y_test, rfr_purchased_predictions_rounded))

plt.scatter(X_test.loc[:,"Age"], Y_test, color='darkorange',
            label='data',s=7)
plt.scatter(X_test.loc[:,"Age"], rfr_purchased_predictions_rounded, color='cornflowerblue',
         label='prediction',s=7)
plt.legend()
plt.show()
# Out:
# Mean Squared Error:  0.6297979953526099
# Mean Absolute Error:  0.5302657807308969
# Mean Squared Error:  0.7581232291420598
# Mean Absolute Error:  0.5415282392026578

# %% [markdown]
# #### Logistic regression:

# %%
from sklearn.linear_model import LogisticRegression

logreg_model = LogisticRegression(random_state=42)
logreg_model.fit(X_train, Y_train)
logreg_model_predictions = logreg_model.predict(X_test)

print('Mean Squared Error: ', mean_squared_error(Y_test, logreg_model_predictions, squared=False))
print('Mean Absolute Error: ', mean_absolute_error(Y_test, logreg_model_predictions))


plt.scatter(X_test.loc[:,"Age"], Y_test, color='darkorange',
            label='data',s=7)
plt.scatter(X_test.loc[:,"Age"], logreg_model_predictions, color='cornflowerblue',
         label='prediction',s=7)
plt.legend()
plt.show()
# Out:
# Mean Squared Error:  0.7106218324146246
# Mean Absolute Error:  0.4983388704318937

# %% [markdown]
# # 6. Fine Tune the Model
#
# - There isn't really anything to fine tune, everything that needed to be done is done
# #### After looking through the RMSEs/MAEs and also the graphs (not really tbh, as aforementioned they kinda suck), it seems like the best choice of a model is linear regression rounded.
# #### YES, THE MODEL THAT ROUNDS TO ALL ZEROS IS THE MOST ACCURATE!! really proves that there truly isn't any (reasonable) correlation (at least not that I could find with my skill)

# %% [markdown]
# # 7. Present the solution
# - First, I imported my data and removed columns of data that are useless
# - Then, I visualized the data to see what correlated most with the purchasing probability (nothing was really found to correlate, so for all future plotting needs I just used age)
# - Then, I split the data into a test and train set, and then tried fitting 3 different models to see which would give the best results
# - Then, I decided on the model that was best at predicting the data primarily based on RMSE/MAE and maybe some of the plotting data (didn't really use the plotted data since there was no found correlation)
# - Finally, deploy the chosen model to a file for usage elsewhere
# #### THE CHOSEN MODEL WAS LINEAR REGRESSION ROUNDED TO THE CLOSEST WHOLE INTEGER

# %% [markdown]
# # 8. Launch the Model System
# - Pickle the model to be loaded whenever needed
# - Unfortunately the pickled file cannot be run alone, the function below MUST be used since it rounds the values which is something the model doesn't do on its own

# %%
#Save the model
import pickle

pickle.dump(lrg_model, open('lrg_model.pkl', 'wb'))

# %% [markdown]
# ### RUN THE CELL BELOW AND INPUT GENDER, AGE, AND ESTIMATEDSALARY

# %%
## FINAL FUNCTION THAT DOES EVERYTHING
import pickle
lrg_model_loaded = pickle.load(open('lrg_model.pkl', 'rb'))

def predict(Gender: str, Age: int, EstimatedSalary: int):
    if Gender == "Female":
        Gender_Female = True
        Gender_Male = False
    elif Gender == "Male":
        Gender_Female = False
        Gender_Male = False
        
    params = [[Age, EstimatedSalary, Gender_Female, Gender_Male]]
    predict_df = pd.DataFrame(params, columns=['Age', 'EstimatedSalary', 'Gender_Female', 'Gender_Male'])
    predicted_value = lrg_model_loaded.predict(predict_df)
    rounded_predicted_value = predicted_value[0].round(0)
    return(rounded_predicted_value)

gender = input("Gender (\"Male\" or \"Female\"): ")
age = int(input("Age:"))
salary = int(input("Estimated salary: "))

             
ret = predict(gender, age, salary)
verdict = ""
if ret == -1:
    verdict = "Returned"
elif ret == 0:
    verdict = "Not Purchased"
elif ret == 1:
    verdict = "Purchased"
else:
    verdict = "Your Model is Severely Broken and heres what you got: " + str(ret)
print("The predicted verdict is: " + verdict + " (" + str(ret) + ")")
# Out:
# Gender ("Male" or "Female"):  Male
# Age: 23
# Estimated salary:  123456
# The predicted verdict is: Not Purchased (0.0)

# %% [markdown]
# - I just wanna advise that most (realistic) input is always gonna output 0. Simply put, linear regression always ends up giving a positive value less than 0.5, causing it to round to 0 every time. It still ended up being the most accurate by quite a lot. Statistically, its best to just always round to zero I guess...
# - Also just to be transparent: if anything seems weird like a comment is referring to something that doesn't make sense in the context of this data/model, it's likely because I copied from my last project to save time and didn't change it (hopefully nothing is like that though)

# %% [markdown]
# # 1. Frame the problem
# Given a sample of several hundred emails labelled as either spam or not spam (aka ham), predict whether an inputted email is spam or not based on differences that can be found between spam emails and normal emails. Ex. words such as "free, email, send" are commonly used in spam emails to attempt to attract a victim. Emails with a high density of these words are likely spam emails.

# %% [markdown]
# # 2. Get the Data
# - The data was provided in a folder called "mail" as 872 text files labelled as either spam emails or non spam (ham) emails.
# - To initially load the data, I loop through every single text file and add its contents to a pandas dataframe.
# - I also have a boolean column for each email that states whether it is spam or not.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

columnaxis = []

for filename in os.listdir("mail"): #loop through a list of every email filename in the mail folder
    if not os.path.isdir(filename):
        with open("mail/" + filename, 'r') as file: #open each file
            spambool = "spm" in filename #create boolean based on whether the email is spam or not
            content = file.read() #get text contents of file, aka the actual email
            row = [spambool, content] #create row array
            columnaxis.append(row) #add to list that will become a dataframe
dataframe = pd.DataFrame(columnaxis, columns=['Spam', 'Content'])

# columns: Spam, Content

# all modifications to dataset go under here
print(str(len(dataframe)) + " rows in dataframe")
# Out:
# 872 rows in dataframe

# %% [markdown]
# # 3. Explore the Data
# - Below is a data explorer that just allows you to look thru the dataset in pages for easy searching (for this email spam project in particular it isn't that useful)

# %%
#copied from project 1, used to explore the data in pages
from IPython.display import clear_output #so that output is cleared after every page to prevent clutter and huge outputs

pd.set_option('display.max_columns', None) #unrestrict amount of columns printable
pd.set_option('display.max_rows', None)  #unrestrict amount of rows printable
pd.set_option('display.max_colwidth', None)  #unrestrict printable width of columns

#a little page search thing to view the data
x = 1
resultsperpage = 10
while x >= 1:
    print("Page " + str(x) + ":")
    clear_output()
    print(dataframe[resultsperpage * (x - 1):resultsperpage * (x)])
    x = int(input("Input a page number: "))

# %% [markdown]
# - Before vizualizing the data, I need to clean the data (see step 4 for details)

# %%
import string #for getting all forms of punctuation to remove
import nltk
nltk.download('punkt') #nltk doesnt work if i dont do this stuff for some reason
nltk.download('wordnet') #nltk doesnt work if i dont do this stuff for some reason
from nltk.stem import PorterStemmer, WordNetLemmatizer#stemming is like getting rid of tenses and stuff to make as many words in common as possible. found out lemmatizing is useless after some tests, for some reason it just removes "s" at the end if it exists
from nltk.tokenize import word_tokenize #split emails into words (better than .split cuz it handles multiple spaces well)

ps = PorterStemmer() #create stemming obj
wnl = WordNetLemmatizer() #create lemming obj
print("THIS CODE TAKES A COUPLE SECONDS TO RUN DUE TO ALL THE STEMMING AND LEMMING...")

def clean(content): #this function will be applied to the contents of each email
    ret = ""
    content = content.translate(str.maketrans('', '', string.punctuation)) #removes punctuation
    for word in word_tokenize(content):
        ret += wnl.lemmatize(ps.stem(word)) + " " #stem and lemmatize then add it to a string
        # if word != wnl.lemmatize(ps.stem(word)): #debug code that would show all the changes made by stemming. HUGE OUTPUT DO NOT UNCOMMENT UNLESS YOU WANT TO DIE
            # print(word + " >> " + wnl.lemmatize(ps.stem(word)))
    return ret
dataframe['ContentCleaned'] = dataframe.Content.apply(clean) #apply above function to every email in df
print("done")
# print(dataframe.Content[1])
# print(dataframe.ContentCleaned[1])
# Out:
# [nltk_data] Downloading package punkt to /home/jupyter-
# [nltk_data]     victorj/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/jupyter-
# [nltk_data]     victorj/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# THIS CODE TAKES A COUPLE SECONDS TO RUN DUE TO ALL THE STEMMING AND LEMMING...
# done

# %% [markdown]
# - To visualize what words are most commonly occuring in this dataset, I created a word cloud. The larger the word, the more often it appears.
# - The word cloud below is for all emails in the dataset

# %%
from wordcloud import WordCloud

text = dataframe["ContentCleaned"].str.cat(sep='\n') #combine EVERY SINGLE ROW OF TEXT into A SINGLE STRING.....
# print(text[:10000]) #just checking that it works lol

wordcloud = WordCloud(width=1600, height=800, random_state=42).generate(text) #make the word cloud with a high resolution to see lots of detail
plt.figure(figsize=(10,5)) #increase size of image
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# - The word cloud that looks through all types of email doesn't really provide any useful insight into patterns that emerge in specific types of email, so now I'll make a word cloud for each specific type of email: spam and ham.

# %% [markdown]
# ### Spam:

# %%
spam_dataframe = dataframe[dataframe.Spam == True]
text = spam_dataframe["ContentCleaned"].str.cat(sep='\n') #combine EVERY SINGLE ROW OF TEXT into A SINGLE STRING.....
# print(text[:10000]) #just checking that it works lol

spam_wordcloud = WordCloud(width=1600, height=800, random_state=42).generate(text) #make the word cloud with a high resolution to see lots of detail
plt.figure(figsize=(10,5)) #increase size of image
plt.imshow(spam_wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ### Ham:

# %%
ham_dataframe = dataframe[dataframe.Spam == False]
text = ham_dataframe["ContentCleaned"].str.cat(sep='\n') #combine EVERY SINGLE ROW OF TEXT into A SINGLE STRING.....
# print(text[:10000]) #just checking that it works lol

ham_wordcloud = WordCloud(width=1600, height=800, random_state=42).generate(text) #make the word cloud with a high resolution to see lots of detail
plt.figure(figsize=(10,5)) #increase size of image
plt.imshow(ham_wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# - After creating the word cloud, it is easy to notice that words like "free", "one", "email", and "3d" appear more often in spam emails, while words like "language", "linguist", "universe", and "conference" appear more often in non spam emails.

# %% [markdown]
# # 4. Prepare the Data
# - Most data prep was done in step 3 due to the nature of the given data, so I will describe each of the data cleaning steps in more detail here.
# - First, I clean the contents of the emails themselves. I remove all the punctuations, then stem and lemmatize every word to ensure that there are as many similar words to each other as possible, which helps with data visualization as well as model accuracy. Also as a result of doing this process, the spaces between words becomes consistent.
# - Next, once this transformation is done, I make a new column with the cleaned version of the email contents. There isn't too much of a reason to keep the old data, but in most practices you would keep it anyway, so it doesn't really matter.
# #### Note for the deployment function: when the deployment function is made, the inputted data will have to be cleaned. I will have to run the inputted email through all the same procedures that the training data went through, so I will have to redo all this data cleaning in the deployment function.
# - That's all the data prep done in step 3, which is all the very major cleaning part
# - Now, lastly, I CountVectorize the emails and make a test train split to ensure that I can have seperate datasets to train my data on and then test my data on.
# #### NOTE FOR COUNTVECTORIZING: Pickle the Countvectorized

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
import pickle

cv = CountVectorizer(decode_error='ignore') #make cv obj

dataframe_X = cv.fit_transform(dataframe['ContentCleaned']) #countvectorizes the cleaned emails, which becomes the x

pickle.dump(cv, open("CountVectorizer.pkl", "wb")) #pickles the fitted countvectorizer object (only way for it to work in deployment, i dont really understand y but yea to me it seems like overfitting considering we didnt get rid of test data but yeaaaa whatever ig probably should make test train b4 but idk and idc)

dataframe_Y = dataframe['Spam'] #gets only the spam boolean column, which becomes the y

X_train, X_test, Y_train, Y_test = train_test_split(dataframe_X, dataframe_Y, test_size=0.3, random_state=42)

# %% [markdown]
# - Now comes the last data prep, which is CountVectorizing the words to see what words appear most often and attach a numerical value to what emails would be spam and what emails would be ham.

# %% [markdown]
# # 5. Model the data
# #### Models that I will try:
# - Linear regression (rounding)
# - Logistic regression
# - Multinomial Naive Bayes classifier

# %% [markdown]
# #### Linear regression:

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error #root of the average of the square of all differences
from sklearn.metrics import mean_absolute_error #all differences have equal weight (average without square)


lrg_model = LinearRegression()
lrg_model.fit(X_train,Y_train)
lrg_model_predictions = lrg_model.predict(X_test)
lrg_model_predictions_rounded = lrg_model_predictions.round(0)

#cannot use score since it requires rounding
print('Mean Squared Error: ', mean_squared_error(Y_test, lrg_model_predictions_rounded, squared=False)) 
print('Mean Absolute Error: ', mean_absolute_error(Y_test, lrg_model_predictions_rounded))
#ends up not being a great rmse i dont think (to be entirely honest i have no clue what im doing for lrg and i dont care enough to find out bc naive_bayes is obv gonna win i just need filler, if i spent some time i could figure it out but i dont have that kind of time rn or ever probably lol)
# Out:
# Mean Squared Error:  1.094748045187909
# Mean Absolute Error:  0.35877862595419846

# %% [markdown]
# #### Logistic regression:

# %%
from sklearn.linear_model import LogisticRegression


logreg_model = LogisticRegression(random_state=42)
logreg_model.fit(X_train, Y_train)
logreg_model_predictions = logreg_model.predict(X_test)

print('Training accuracy: ',logreg_model.score(X_train,Y_train)*100)
print('Testing accuracy: ',logreg_model.score(X_test,Y_test)*100)
# Out:
# Training accuracy:  100.0
# Testing accuracy:  97.70992366412213

# %% [markdown]
# #### Naive Bayes:

# %%
from sklearn.naive_bayes import MultinomialNB


mnb_model = MultinomialNB()
mnb_model.fit(X_train,Y_train)

print('Training accuracy: ',mnb_model.score(X_train,Y_train)*100)
print('Testing accuracy: ',mnb_model.score(X_test,Y_test)*100)
# Out:
# Training accuracy:  99.50819672131146
# Testing accuracy:  98.47328244274809

# %% [markdown]
# # 6. Fine Tune the Model
#
# - There isn't really anything to fine tune, everything that needed to be done is done and all thats left is to decide which one performs best
# #### After looking through the test accuracy scores, it seems like the best choice of a model is Naive Bayes.

# %% [markdown]
# # 7. Present the solution
# - First, I imported my data and formatted my data into a pandas dataframe.
# - Then, I cleaned my data to ensure that common words would be put together and that once trained the spam detection would be more accurate
# - Then, I visualized the data to see what words correlated most with the spam probability
# - Then, I split the data into a test and train set, and then tried fitting 3 different models to see which would give the best results
# - Then, I decided on the model that was best at predicting the data primarily based on accuracy scores
# - Finally, deploy the chosen model to a file for usage elsewhere
# #### THE CHOSEN MODEL WAS NAIVE BAYES

# %% [markdown]
# # 8. Launch the Model System
# - Pickle the model to be loaded whenever needed
# - Unfortunately the pickled file cannot be run alone, the function below MUST be used since it cleans the input which is something the model doesn't do on its own

# %%
#Save the model
import pickle

pickle.dump(mnb_model, open('mnb_model.pkl', 'wb'))

# %% [markdown]
# ### RUN THE CELL BELOW AND INPUT A LARGE STRING THAT IS THE EMAIL CONTENTS

# %%
## FINAL FUNCTION THAT DOES EVERYTHING
import pickle
from sklearn.feature_extraction.text import CountVectorizer
mnb_model_loaded = pickle.load(open('mnb_model.pkl', 'rb'))

def predict(email_contents: str):
    
    import string
    import nltk
    nltk.download('punkt')
    nltk.download('wordnet')
    from nltk.stem import PorterStemmer, WordNetLemmatizer
    from nltk.tokenize import word_tokenize
    
    ps = PorterStemmer()
    wnl = WordNetLemmatizer()
    
    def clean(content):
        ret = ""
        content = content.translate(str.maketrans('', '', string.punctuation)) #removes punctuation
        for word in word_tokenize(content):
            ret += wnl.lemmatize(ps.stem(word)) + " " #stem and lemmatize then add it to a string
        return ret
    email_contents = clean(email_contents) #apply above function to the inputted email

    
    cv = pickle.load(open("CountVectorizer.pkl", "rb")) #load countvectorizer from b4 or stuff breaks
    
    # creating feature variables
    email_contents_cv = cv.transform([email_contents]) #get all columns but the spam column
    
    # params = [[email_contents_cv]]
    # predict_df = pd.DataFrame(params, columns=['ContentCleaned'])
    predicted_value = mnb_model_loaded.predict(email_contents_cv)
    return(predicted_value)

email_input = input("Input email contents here: ")
             
ret = predict(email_input)

verdict = ""
if ret == False:
    verdict = "Not Spam"
elif ret == True:
    verdict = "Spam"
else:
    verdict = "Your Model is Broken"
print("Your email is: " + verdict)
# Out:
# Input email contents here:  sdfsdf adfasd fasdfasdfasdf asdfasd fasd fasdf
# Your email is: Not Spam
# [nltk_data] Downloading package punkt to /home/jupyter-
# [nltk_data]     victorj/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/jupyter-
# [nltk_data]     victorj/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# - Just to be transparent: if anything seems weird like a comment is referring to something that doesn't make sense in the context of this data/model, it's likely because I copied from my last project to save time and didn't change it (hopefully nothing is like that though)
# - Also just to mention, I never ended up fully understanding how to implement a linear regression to get it to work, and I never fully understood how CountVectorizer actually works and why it needs to be pickled and how that all works. Just wanna point out my faults so that it doesn't seem like I'm crazy knowledgeable when in reality I bsed like half the stuff
# - I also think the CountVectorizer is being overfit on test data so... oh well I guess lol
# - This was a confusing project and I'm still lost but it works I guess and it's finalized enough for me to be fine leaving it the way it is
